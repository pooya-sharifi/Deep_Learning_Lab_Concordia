# %% [markdown]
# <a href="https://colab.research.google.com/github/pooya-sharifi/Deep_Learning_Lab_Concordia/blob/main/Copy_of_2024_Lab6_Ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 6: Word Embeddings and RNNs
#
# This lab covers the following topics:
# - Word encodings and embeddings.
# - Recurrent neural networks (RNNs).
# - Long-short term memory (LSTM).

# %% [markdown]
# ## Exercise 1: Word Embeddings

# %% [markdown]
# ### Exercise 1.1
# Consider the limited vocabulary list below

# %%
vocab = ["the", "quick", "brown", "sly", "fox", "jumped", "over", "a", "lazy", "dog", "and","found","lion"]
print(len(vocab))
# Out:
# 13

# %% [markdown]
# Write a function to create **one hot encodings** of the words. The function maps each word to a vector, where it's location in the vocab list is indicated by 1 and all other entries are zero.
#
# For example "quick" should map to a torch tensor of dimension 1 with entries [0,1,0....0].
#
# Create an extra category for words not in the vocabulary

# %%
def one_hot_embedding(token, vocab):
  """
  Token should be a list of words or an indvidual word of length W.
  The output shouild be a torch tensor fo size W x (V+1) which gives the one hot encoding for all W tokens
  """
#   num_words = len(token)
#   vocab_size = len(vocab)
#   vector = torch.zeros((num_words, vocab_size))

#   for i, word in enumerate(token):
#         if word in vocab:
#             index = vocab.index(word)
#             vector[i, index] = 1
  num_vocab = len(vocab)
  inds = torch.tensor([vocab.index(word) if word in vocab else num_vocab for word in token]).unsqueeze(1)
  zeros = torch.zeros(len(token), num_vocab+1)
  vector = zeros.scatter(dim=1, index=inds, value=1)

  return vector

# %% [markdown]
# ### Exercise 1.2
#
# Create a `nn.module` that:
#
# 1. Takes in a single sentence (a python list).
# 2. Finds the one hot encoding of each word using the function created in exercise 1.1.
# 3. Finds the "word embedding" of each word that is $D$-dimensional using the `EmbedddingTable`.
# 4. Returns the average of the word embeddings as a torch vector of size $D$.

# %%
import torch.nn as nn
import torch

class MyWordEmbeddingBag(nn.Module):
    def __init__(self, dim):
        super(MyWordEmbeddingBag, self).__init__()

        self.EmbeddingTable = nn.Parameter(torch.randn(len(vocab)+1,dim))

    def forward(self, inputList):
        # Your answer here
        # embeddings = one_hot_embedding(inputList,vocab)
        # embeddings = torch.tensor(embeddings, dtype=torch.float)
        # x = embeddings @ self.EmbeddingTable
        embeddings = one_hot_embedding(inputList,vocab)
        x = embeddings @ self.EmbeddingTable
        return x.mean(dim=0)

        # return vector

# %% [markdown]
# ### Exercise 1.3
#
# Instantiate the model with vectors of size $D$= 100 and forward pass the following sentences through your module

# %%
sent1 = ["the", "quick", "brown"]
sent2 = ["the", "sly", "fox", "jumped"]
sent3 = ["the", "dog", "found","a","lion"]

#Instantiate model
my_model = MyWordEmbeddingBag(100)

#forward pass sentences
assert(len(my_model(sent1))==100)
assert(len(my_model(sent2))==100)
assert(len(my_model(sent3))==100)

# %% [markdown]
# ### Exercise 1.4
#
# Compute the euclidean distance between "fox" and "dog" using the randomly initialized embedding table in your model above.
#
# **Note**: As this is randomly initialized, the distances will also be random in this case. However a trained model using word embeddings will often exhibit closer distances between related words, depending on objective.

# %%
(my_model(['fox'])-my_model(['dog'])).norm()
# Out:
# tensor(14.7807, grad_fn=<LinalgVectorNormBackward0>)

# %% [markdown]
# ## Exercise 2: Recurrent Neural Networks

# %% [markdown]
# We will experiment with recurrent networks using the MNIST dataset.

# %%
import torchvision
import torch
import torchvision.transforms as transforms

from torch.utils.data import Subset

### Hotfix for very recent MNIST download issue https://github.com/pytorch/vision/issues/1938
from six.moves import urllib
opener = urllib.request.build_opener()
opener.addheaders = [('User-agent', 'Mozilla/5.0')]
urllib.request.install_opener(opener)
###

dataset = torchvision.datasets.MNIST('./', download=True, transform=transforms.Compose([transforms.ToTensor()]), train=True)
train_indices = torch.arange(0, 10000)
train_dataset = Subset(dataset, train_indices)

dataset=torchvision.datasets.MNIST('./', download=True, transform=transforms.Compose([transforms.ToTensor()]), train=False)
test_indices = torch.arange(0, 10000)
test_dataset = Subset(dataset, test_indices)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 15.9MB/s]
# Extracting ./MNIST/raw/train-images-idx3-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 476kB/s]
# Extracting ./MNIST/raw/train-labels-idx1-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.39MB/s]
# Extracting ./MNIST/raw/t10k-images-idx3-ubyte.gz to ./MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 6.56MB/s]
# Extracting ./MNIST/raw/t10k-labels-idx1-ubyte.gz to ./MNIST/raw

# %%
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64,
                                          shuffle=True, num_workers=0)

test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=16,
                                          shuffle=False, num_workers=0)

# %% [markdown]
# ### Exercise 2.1
#
# Consider the following script (modified from https://github.com/yunjey/pytorch-tutorial/blob/master/tutorials/02-intermediate/recurrent_neural_network/main.py) which trains an RNN on the MNIST data.
#
# Here we can consider each column of the image as an input for each step of the RNN. After 28 steps the model applies a linear layer + cross-entropy loss. We will use this to familiarize ourselves with the nn.RNN module and the nn.LSTM module.
#
# First run the cell below

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms


# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyper-parameters
sequence_length = 28
input_size = 28
hidden_size = 128
num_layers = 2
num_classes = 10
batch_size = 100
num_epochs = 2
learning_rate = 0.01


# Recurrent neural network (many-to-one)
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        # Set initial hidden and cell states
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

        # Forward propagate RNN
        out , _ = self.rnn(x, h0)  # out: tensor of shape (batch_size, seq_length, hidden_size)

        # Decode the hidden state of the last time step
        out = self.fc(out[:, -1, :])
        return out

model = RNN(input_size, hidden_size, num_layers, num_classes).to(device)


# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Train the model
total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        #Gradient clipping
        #torch.nn.utils.clip_grad_norm_(model.parameters(), 0.2)
        print("Gradient norm for model.rnn.weight_ih_l0:", model.rnn.weight_ih_l0.grad.norm())
        optimizer.step()

        if (i+1) % 10 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))

# Test the model
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print('Test Accuracy of the model on the 10000 test images: {} %'.format(100 * correct / total))
# Out:
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0541, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0722, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2796, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0374, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0373, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0323, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0200, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0122, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0258, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.9624, device='cuda:0')
# Epoch [1/2], Step [10/157], Loss: 2.2488
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0327, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0178, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0332, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0563, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1327, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1093, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4706, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3750, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0458, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0762, device='cuda:0')
# Epoch [1/2], Step [20/157], Loss: 2.5976
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0626, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0774, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1033, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1027, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0828, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1305, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1395, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1293, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1157, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0946, device='cuda:0')
# Epoch [1/2], Step [30/157], Loss: 2.0757
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1378, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1191, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1024, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1358, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1052, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1309, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0736, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0949, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1097, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0893, device='cuda:0')
# Epoch [1/2], Step [40/157], Loss: 2.1770
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0768, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0813, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1253, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0999, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1040, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1959, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1304, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3139, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2630, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3015, device='cuda:0')
# Epoch [1/2], Step [50/157], Loss: 2.1943
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2185, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1109, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2520, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1589, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1734, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1026, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1007, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1254, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2248, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1244, device='cuda:0')
# Epoch [1/2], Step [60/157], Loss: 1.8371
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1565, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1588, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1396, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1503, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1137, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0760, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0888, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1115, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0708, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0714, device='cuda:0')
# Epoch [1/2], Step [70/157], Loss: 1.7588
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0502, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1332, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2483, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1696, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1570, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1363, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2208, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1267, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2064, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3528, device='cuda:0')
# Epoch [1/2], Step [80/157], Loss: 1.9387
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1067, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1606, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2602, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2856, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.9483, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1208, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0434, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1402, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1024, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0348, device='cuda:0')
# Epoch [1/2], Step [90/157], Loss: 2.1678
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0274, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0355, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0652, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1212, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0680, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1585, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0530, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1696, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2545, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0756, device='cuda:0')
# Epoch [1/2], Step [100/157], Loss: 2.1687
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1502, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1037, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0906, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0885, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0447, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1011, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0741, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0497, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0667, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0609, device='cuda:0')
# Epoch [1/2], Step [110/157], Loss: 1.9512
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0712, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0778, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0757, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0652, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0618, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0578, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0616, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1457, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0572, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1131, device='cuda:0')
# Epoch [1/2], Step [120/157], Loss: 1.8919
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0495, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1485, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0889, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2092, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0775, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1126, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1220, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1611, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1041, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1530, device='cuda:0')
# Epoch [1/2], Step [130/157], Loss: 1.6524
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0862, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0526, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1033, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1109, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1044, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0615, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1774, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1109, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0948, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1714, device='cuda:0')
# Epoch [1/2], Step [140/157], Loss: 1.7395
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1660, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2301, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1724, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1487, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1275, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1456, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2340, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2065, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1359, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1135, device='cuda:0')
# Epoch [1/2], Step [150/157], Loss: 1.5105
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1078, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1095, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0991, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1074, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1415, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1457, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1976, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0686, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0752, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1890, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1225, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1111, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1678, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2150, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1292, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2048, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1601, device='cuda:0')
# Epoch [2/2], Step [10/157], Loss: 1.8260
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2485, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1041, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1377, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2127, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1824, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1254, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2889, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1456, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0618, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0716, device='cuda:0')
# Epoch [2/2], Step [20/157], Loss: 1.8167
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2110, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1096, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1608, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0901, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0652, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1384, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1955, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0797, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1070, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1870, device='cuda:0')
# Epoch [2/2], Step [30/157], Loss: 1.6632
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2647, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0927, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1082, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0847, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1039, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1047, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1766, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0816, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1482, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1466, device='cuda:0')
# Epoch [2/2], Step [40/157], Loss: 1.6609
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1179, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0795, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0806, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2133, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1843, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1999, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1945, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1324, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3324, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2455, device='cuda:0')
# Epoch [2/2], Step [50/157], Loss: 1.9673
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3247, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2360, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1182, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0880, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1274, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0729, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1074, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1233, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2117, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0968, device='cuda:0')
# Epoch [2/2], Step [60/157], Loss: 1.7101
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1229, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2874, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1161, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1417, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0386, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1142, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1810, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2301, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1101, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1024, device='cuda:0')
# Epoch [2/2], Step [70/157], Loss: 1.4986
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2214, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0516, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3673, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2726, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1505, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3196, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3358, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3802, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0740, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6596, device='cuda:0')
# Epoch [2/2], Step [80/157], Loss: 1.5679
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0929, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0672, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1651, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0410, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0847, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0659, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0655, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0457, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0779, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0750, device='cuda:0')
# Epoch [2/2], Step [90/157], Loss: 1.5676
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0643, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0581, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0617, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0484, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0627, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0907, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1129, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1138, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1335, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0497, device='cuda:0')
# Epoch [2/2], Step [100/157], Loss: 1.4946
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1272, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1242, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0740, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1313, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1013, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2443, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1937, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4749, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2034, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2535, device='cuda:0')
# Epoch [2/2], Step [110/157], Loss: 1.8063
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0938, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2547, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0703, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1022, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2917, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6790, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0522, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0668, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2120, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4317, device='cuda:0')
# Epoch [2/2], Step [120/157], Loss: 1.9000
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2708, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0579, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1660, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1568, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1952, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0933, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1636, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0727, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0611, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0727, device='cuda:0')
# Epoch [2/2], Step [130/157], Loss: 1.9646
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0513, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0421, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0759, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0714, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0840, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1504, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3116, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1434, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0987, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1448, device='cuda:0')
# Epoch [2/2], Step [140/157], Loss: 2.1025
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1373, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1081, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1339, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1433, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1978, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1108, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0832, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2557, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2493, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1802, device='cuda:0')
# Epoch [2/2], Step [150/157], Loss: 1.5633
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0930, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4365, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2987, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1172, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1055, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3256, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0986, device='cuda:0')
# Test Accuracy of the model on the 10000 test images: 36.01 %

# %% [markdown]
# ### Exercise 2.2
#
# Modify the above code (no need to create a new cell) to print the gradient norm of some of the parameters after backward in the the first minibatch.
#
# Do this for the following weight parameter: model.rnn.weight_ih_l0.

# %% [markdown]
# ### Exercise 2.3
#
# Modify the code (in a new cell below) to use LSTM  (and remove the gradient clipping) and rerun the code.
#
# **Note**: This is essentially what is done in the original script linked above which you may check for reference or if you get stuck.
#
# Run with LSTM and compare the accuracy and the gradient norm for weight_ih_l0 of the RNN.

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms


# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyper-parameters
sequence_length = 28
input_size = 28
hidden_size = 128
num_layers = 2
num_classes = 10
batch_size = 100
num_epochs = 2
learning_rate = 0.01


# Recurrent neural network (many-to-one)
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(RNN, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.rnn = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        # Set initial hidden and cell states
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

        # Forward propagate RNN
        out , _ = self.rnn(x, (h0,c0))  # out: tensor of shape (batch_size, seq_length, hidden_size)

        # Decode the hidden state of the last time step
        out = self.fc(out[:, -1, :])
        return out

model = RNN(input_size, hidden_size, num_layers, num_classes).to(device)


# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Train the model
total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        #Gradient clipping
        #torch.nn.utils.clip_grad_norm_(model.parameters(), 0.2)
        print("Gradient norm for model.rnn.weight_ih_l0:", model.rnn.weight_ih_l0.grad.norm())
        optimizer.step()

        if (i+1) % 10 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))

# Test the model
model.eval()
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print('Test Accuracy of the model on the 10000 test images: {} %'.format(100 * correct / total))
# Out:
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0051, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0169, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0202, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0374, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0525, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0408, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0883, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1682, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.9922, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.1851, device='cuda:0')
# Epoch [1/2], Step [10/157], Loss: 2.5999
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.9595, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1950, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3400, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4274, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2306, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.8805, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4788, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4032, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4496, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4837, device='cuda:0')
# Epoch [1/2], Step [20/157], Loss: 1.6917
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5781, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6732, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4315, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5568, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4565, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5508, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6084, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7553, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5245, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.3806, device='cuda:0')
# Epoch [1/2], Step [30/157], Loss: 1.2648
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.2683, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7775, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.9799, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5377, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5207, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.1688, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.8853, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5837, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.9552, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.4350, device='cuda:0')
# Epoch [1/2], Step [40/157], Loss: 1.2723
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.8447, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.8477, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.4313, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7581, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4606, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.9288, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3982, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4024, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.0110, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.8266, device='cuda:0')
# Epoch [1/2], Step [50/157], Loss: 1.3370
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.9160, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4926, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.3063, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6472, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4768, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4510, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6753, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7726, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.1315, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7051, device='cuda:0')
# Epoch [1/2], Step [60/157], Loss: 0.8026
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5695, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6724, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4969, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.9402, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1980, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.8874, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.9085, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.4551, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4601, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4155, device='cuda:0')
# Epoch [1/2], Step [70/157], Loss: 0.7095
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4361, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7505, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7319, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5769, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.8475, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6803, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4969, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6191, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.8885, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6412, device='cuda:0')
# Epoch [1/2], Step [80/157], Loss: 0.6981
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6581, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.9448, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6398, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3915, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5327, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4707, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.9003, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.8557, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6894, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.8126, device='cuda:0')
# Epoch [1/2], Step [90/157], Loss: 0.7214
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.0452, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4426, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5213, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7395, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5712, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5667, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4512, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.0171, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3935, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4116, device='cuda:0')
# Epoch [1/2], Step [100/157], Loss: 0.5879
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5601, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3190, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4081, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3813, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6068, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4124, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5398, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4167, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.8227, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.8455, device='cuda:0')
# Epoch [1/2], Step [110/157], Loss: 0.7116
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4059, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.2610, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7686, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.8803, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6497, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.5479, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3347, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(2.1407, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7360, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5322, device='cuda:0')
# Epoch [1/2], Step [120/157], Loss: 0.5805
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4614, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5791, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2379, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2038, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5834, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3501, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3820, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5854, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6713, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.0804, device='cuda:0')
# Epoch [1/2], Step [130/157], Loss: 0.6881
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5795, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.8710, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5698, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3299, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.9595, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.9573, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4446, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2725, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5572, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6658, device='cuda:0')
# Epoch [1/2], Step [140/157], Loss: 0.5579
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3776, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3661, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.0035, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3393, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4803, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4326, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2673, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4095, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5888, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3708, device='cuda:0')
# Epoch [1/2], Step [150/157], Loss: 0.3425
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4691, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5509, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.0251, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4398, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5311, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.9141, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(2.3348, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7194, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.6314, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4887, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5754, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5454, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2046, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7354, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5842, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5618, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3207, device='cuda:0')
# Epoch [2/2], Step [10/157], Loss: 0.6483
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6209, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3152, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.1117, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2695, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1411, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6042, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5250, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.9359, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7391, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5515, device='cuda:0')
# Epoch [2/2], Step [20/157], Loss: 0.3414
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2683, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2521, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.1386, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.5109, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6168, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4261, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4771, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5926, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4394, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4832, device='cuda:0')
# Epoch [2/2], Step [30/157], Loss: 0.4025
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4409, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4532, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4115, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3770, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4026, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3959, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2618, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5384, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3502, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7022, device='cuda:0')
# Epoch [2/2], Step [40/157], Loss: 0.8110
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4234, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5706, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2156, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4530, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4230, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.8181, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7558, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.9110, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3125, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4410, device='cuda:0')
# Epoch [2/2], Step [50/157], Loss: 0.2628
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3429, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2323, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4299, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3115, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5361, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1049, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4718, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.9074, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4118, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7770, device='cuda:0')
# Epoch [2/2], Step [60/157], Loss: 0.3153
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2258, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6330, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4053, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5070, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2411, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4053, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4014, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4108, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2379, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4631, device='cuda:0')
# Epoch [2/2], Step [70/157], Loss: 0.3832
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3247, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5929, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1578, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.8801, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4088, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7381, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5207, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6107, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2869, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4082, device='cuda:0')
# Epoch [2/2], Step [80/157], Loss: 0.4248
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3930, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3807, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2488, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3936, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1702, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3005, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3026, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3929, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2693, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1525, device='cuda:0')
# Epoch [2/2], Step [90/157], Loss: 0.3270
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1547, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6836, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1983, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3308, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7932, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.8031, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3026, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3159, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1935, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2790, device='cuda:0')
# Epoch [2/2], Step [100/157], Loss: 0.2755
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3409, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5323, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7997, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4108, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1335, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2277, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6054, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5078, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3178, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7215, device='cuda:0')
# Epoch [2/2], Step [110/157], Loss: 0.3120
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.0443, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2177, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4050, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1976, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6602, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3435, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4685, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2903, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3535, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3276, device='cuda:0')
# Epoch [2/2], Step [120/157], Loss: 0.2718
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.1124, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(1.2586, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4418, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.7401, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2244, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4341, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1777, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3999, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5007, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5701, device='cuda:0')
# Epoch [2/2], Step [130/157], Loss: 0.2457
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3178, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3544, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1334, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2548, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3555, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.6289, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1984, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4417, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.2961, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3884, device='cuda:0')
# Epoch [2/2], Step [140/157], Loss: 0.1382
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5350, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3845, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3809, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5343, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5861, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3139, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4945, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.8227, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5984, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.9605, device='cuda:0')
# Epoch [2/2], Step [150/157], Loss: 0.2252
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.5924, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3978, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4451, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.3067, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1177, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.4150, device='cuda:0')
# Gradient norm for model.rnn.weight_ih_l0: tensor(0.1416, device='cuda:0')
# Test Accuracy of the model on the 10000 test images: 92.42 %
